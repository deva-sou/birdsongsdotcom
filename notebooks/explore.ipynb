# %%
# Libraries Imports
import pandas as pd
import librosa
import matplotlib.pyplot as ply

# %%
# Variables
audio_path = "/home/devasou/code/deva-sou/birdsongsdotcom/data/XC1148089 - New Ireland Friarbird - Philemon eichhorni.wav"

# %% [markdown]
# # Audio Exploration

# %%
y, sr = librosa.load(audio_path, sr=None)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 y, sr = librosa.load(audio_path, sr=None)
#
# File ~/.pyenv/versions/3.12.9/envs/devasou/lib/python3.12/site-packages/lazy_loader/__init__.py:79, in attach.<locals>.__getattr__(name)
#      77 submod_path = f"{package_name}.{attr_to_modules[name]}"
#      78 submod = importlib.import_module(submod_path)
# ---> 79 attr = getattr(submod, name)
#      81 # If the attribute lives in a file (module) with the same
#      82 # name as the attribute, ensure that the attribute and *not*
#      83 # the module is accessible on the package.
#      84 if name == attr_to_modules[name]:
#
# File ~/.pyenv/versions/3.12.9/envs/devasou/lib/python3.12/site-packages/lazy_loader/__init__.py:78, in attach.<locals>.__getattr__(name)
#      76 elif name in attr_to_modules:
# ...

# %%
import bz2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import bz2
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/bz2.py:17
#      14 import os
#      15 import _compression
# ---> 17 from _bz2 import BZ2Compressor, BZ2Decompressor
#      20 _MODE_CLOSED   = 0
#      21 _MODE_READ     = 1
#
# ImportError: libbz2.so.1.0: cannot open shared object file: No such file or directory

# %%
import subprocess
print(subprocess.run(["which", "python"], capture_output=True, text=True).stdout)
# Out:
# /home/devasou/.pyenv/versions/3.12.9/envs/devasou/bin/python

# %%
import _bz2
print(_bz2.__file__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import _bz2
#       2 print(_bz2.__file__)
#
# ImportError: libbz2.so.1.0: cannot open shared object file: No such file or directory

# %%
# !ldd $(python -c "import _bz2; print(_bz2.__file__)") | grep bz2
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# ImportError: libbz2.so.1.0: cannot open shared object file: No such file or directory
# ldd: missing file arguments
# Try `ldd --help' for more information.

# %%
# !find ~/.pyenv/versions/3.12.9 -name "_bz2*.so"
# Out:
# /home/devasou/.pyenv/versions/3.12.9/lib/python3.12/lib-dynload/_bz2.cpython-312-x86_64-linux-gnu.so

# %%
# !ldd /home/devasou/.pyenv/versions/3.12.9/lib/python3.12/lib-dynload/_bz2.cpython-312-x86_64-linux-gnu.so | grep bz2
# Out:
# 	libbz2.so.1.0 => not found

# %%
# !readelf -d /home/devasou/.pyenv/versions/3.12.9/lib/python3.12/lib-dynload/_bz2.cpython-312-x86_64-linux-gnu.so | grep -i 'rpath\|runpath'
# Out:
#  0x000000000000001d (RUNPATH)            Library runpath: [/home/devasou/.pyenv/versions/3.12.9/lib]
